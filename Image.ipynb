# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix

import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Run this cell to make sure that Tensorflow can identify your GPU if you are using a GPU
#physical_devices = tf.config.experimental.list_physical_devices('GPU')
#print("Num GPUs Available: ", len(physical_devices))
#tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# Downloading MobileNet Model
mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
# Building a function to preprocess the Images with MobileNet Preprocessing function
def prepare_image(file):
    img_path = ''
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
# View the first image in the data set
from IPython.display import Image
Image(filename='1.jpg', width=300, height=200)

# %%
# Preprocess the image and display the possible predictions for the image (mostly the top 5 predictions)
preprocessed_image = prepare_image('1.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)  #Top five predictions from the 1000 possible ImageNet classes
results
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 10us/step
# [[('n02412080', 'ram', 0.4714562),
#   ('n02415577', 'bighorn', 0.2353174),
#   ('n02091244', 'Ibizan_hound', 0.068570144),
#   ('n02113799', 'standard_poodle', 0.05222176),
#   ('n02091134', 'whippet', 0.04761752)]]

# %%
# Viewing the second image in the data set
Image(filename='2.jpg', width=300, height=200)

# %%
# Preprocess the image and display the possible predictions for the image (mostly the top 5 predictions)
preprocessed_image = prepare_image('2.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02123045', 'tabby', 0.46385273),
#   ('n02123159', 'tiger_cat', 0.37796545),
#   ('n02124075', 'Egyptian_cat', 0.1443934),
#   ('n02129604', 'tiger', 0.008714657),
#   ('n04493381', 'tub', 0.0003783226)]]

# %%
# Viewing the second image in the data set
Image(filename='3.jpg', width=300, height=200)

# %%
# Preprocess the image and display the possible predictions for the image (mostly the top 5 predictions)
preprocessed_image = prepare_image('3.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02389026', 'sorrel', 0.99312496),
#   ('n02087394', 'Rhodesian_ridgeback', 0.003164781),
#   ('n02422106', 'hartebeest', 0.0019402901),
#   ('n02091831', 'Saluki', 0.00064137264),
#   ('n02100583', 'vizsla', 0.0001803421)]]

# %%
# Viewing the second image in the data set
Image(filename='4.jpg', width=300, height=200)

# %%
# Preprocess the image and display the possible predictions for the image (mostly the top 5 predictions)
preprocessed_image = prepare_image('4.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02106662', 'German_shepherd', 0.9554639),
#   ('n02105162', 'malinois', 0.025510399),
#   ('n02111129', 'Leonberg', 0.010851312),
#   ('n02114367', 'timber_wolf', 0.0024673198),
#   ('n03803284', 'muzzle', 0.0011994406)]]

# %%
# Viewing the second image in the data set
Image(filename='5.jpg', width=300, height=200)

# %%
# Preprocess the image and display the possible predictions for the image (mostly the top 5 predictions)
preprocessed_image = prepare_image('5.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02092339', 'Weimaraner', 0.8453117),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.019893253),
#   ('n02099712', 'Labrador_retriever', 0.019852828),
#   ('n02100583', 'vizsla', 0.017320255),
#   ('n02087394', 'Rhodesian_ridgeback', 0.0154532315)]]

# %%
# Viewing the second image in the data set
Image(filename='6.jpeg', width=300, height=200)

# %%
# Preprocess the image and display the possible predictions for the image (mostly the top 5 predictions)
preprocessed_image = prepare_image('6.jpeg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02992529', 'cellular_telephone', 0.5273938),
#   ('n04074963', 'remote_control', 0.18059726),
#   ('n04423845', 'thimble', 0.05680978),
#   ('n03843555', 'oil_filter', 0.040851913),
#   ('n03047690', 'clog', 0.024687553)]]
